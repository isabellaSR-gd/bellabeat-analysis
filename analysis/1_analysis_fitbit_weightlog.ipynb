# %%
import pandas as pd

# %%
df = pd.read_csv('D:/python/bellabeat-analysis/database/fitbit-data/weightLogInfo_merged.csv')

# %%
df.columns
# Out:
# Index(['Id', 'Date', 'WeightKg', 'WeightPounds', 'Fat', 'BMI',
#        'IsManualReport', 'LogId'],
#       dtype='object')

# %%
df[df['BMI']> 25].sort_values('BMI', ascending= False )
# Out:
#             Id                   Date    WeightKg  WeightPounds  Fat  \
# 1   1927972279   4/10/2016 6:33:26 PM  129.600006    285.719105  NaN
# 6   4445114986  3/30/2016 11:59:59 PM   92.400002    203.707134  NaN
# 23  8253242879   4/7/2016 11:59:59 PM   75.599998    166.669467  NaN
# 7   4558609924   4/8/2016 11:59:59 PM   69.400002    153.000813  NaN
# 8   4702921684   4/4/2016 11:59:59 PM   99.699997    219.800869  NaN
# 25  8877689391    4/4/2016 6:53:43 AM   86.599998    190.920316  NaN
# 27  8877689391    4/6/2016 6:49:31 AM   86.300003    190.258939  NaN
# 31  8877689391   4/11/2016 6:58:09 AM   86.099998    189.818004  NaN
# 26  8877689391    4/5/2016 6:40:15 AM   86.000000    189.597545  NaN
# 32  8877689391   4/12/2016 6:47:11 AM   85.800003    189.156628  NaN
# 24  8877689391    4/1/2016 6:49:40 AM   85.500000    188.495234  NaN
# 30  8877689391    4/9/2016 8:06:12 AM   85.400002    188.274775  NaN
# 28  8877689391    4/7/2016 6:15:08 AM   85.099998    187.613382  NaN
# ...

# %% [markdown]
# Apenas 15 pessoas dos dados usuárias do fit estão acima do peso, e apenas 1 delas tem obesidade grau 2 e apenas 1 tem obesidade grau 3

# %% [markdown]
# próximos passos: analisar os dados desse grupo amostral nos outros csv's
